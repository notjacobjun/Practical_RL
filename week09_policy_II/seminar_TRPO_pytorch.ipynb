# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# Selecting previously unselected package xvfb.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.13_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.13) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.13) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Starting virtual X frame buffer: Xvfb.

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
from typing import Tuple
# !pip install gym[classic_control]

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[classic_control] in /usr/local/lib/python3.8/dist-packages (0.25.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym[classic_control]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from gym[classic_control]) (5.1.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from gym[classic_control]) (1.21.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym[classic_control]) (1.5.0)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      |████████████████████████████████| 18.3 MB 4.5 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0->gym[classic_control]) (3.11.0)
# Installing collected packages: pygame
# Successfully installed pygame-2.1.0

# %%
import gym

env = gym.make("Acrobot-v1")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# Action Space Discrete(3)
# /usr/local/lib/python3.8/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.8/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
from PIL import Image

Image.fromarray(env.render('rgb_array'))
# Out:
# /usr/local/lib/python3.8/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F2C02619FD0>

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $\pi_\theta \left( a \middle| s \right)$.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
from torch.nn.modules.activation import ReLU
class TRPOAgent(nn.Module):
    def __init__(self, state_shape: Tuple[int], n_actions: int):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple:
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        nn.Module.__init__(self)

        assert isinstance(state_shape, tuple)
        assert len(state_shape) == 1
        input_dim = state_shape[0]
        
        # Prepare your model here.
        self.action_network = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions),
            nn.ReLU(),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, states: torch.Tensor):
        """
        takes agent's observation, returns log-probabilities
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for the given states.
        log_probs = self.action_network(states)
        
        return log_probs

    def get_log_probs(self, states: torch.Tensor):
        '''
        Log-probs for training
        '''
        return self.forward(states)

    def get_probs(self, states: torch.Tensor):
        '''
        Probs for interaction
        '''
        return torch.exp(self.forward(states))

    def act(self, obs: np.ndarray, sample: bool = True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        with torch.no_grad():
            probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)
# Out:
# <>:49: DeprecationWarning: invalid escape sequence \p

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(torch.tensor(env.reset()[np.newaxis], dtype=torch.float32))
assert (
    isinstance(log_probs, torch.Tensor) and
    log_probs.requires_grad
), "log_probs must be a torch.Tensor with grad"
assert log_probs.shape == (1, n_actions)
sums = torch.exp(log_probs).sum(dim=1)
assert torch.allclose(sums, torch.ones_like(sums))

# Demo use
print("sampled:", [agent.act(env.reset()) for _ in range(5)])
print("greedy:", [agent.act(env.reset(), sample=False) for _ in range(5)])
# Out:
# sampled: [(1, array([0.36560845, 0.3320695 , 0.30232212], dtype=float32)), (2, array([0.36625656, 0.33460203, 0.29914147], dtype=float32)), (0, array([0.36747777, 0.3323966 , 0.3001257 ], dtype=float32)), (1, array([0.3704382 , 0.33118322, 0.29837862], dtype=float32)), (2, array([0.36880496, 0.33207694, 0.29911807], dtype=float32))]
# greedy: [(0, array([0.37104896, 0.3310713 , 0.2978798 ], dtype=float32)), (0, array([0.37041503, 0.3332025 , 0.29638252], dtype=float32)), (0, array([0.36555275, 0.33576536, 0.29868189], dtype=float32)), (0, array([0.3690118 , 0.33306983, 0.2979184 ], dtype=float32)), (0, array([0.36742884, 0.33123598, 0.3013351 ], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = [torch.ravel(param.detach()) for param in model.parameters()]
    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.shape)))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].reshape(param.shape)
        )
        prev_ind += flat_size

# %% [markdown]
# Compute cumulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cumulative_returns(r, gamma=1):
    """
    Computes cumulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cumulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, done, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if done or total_timesteps >= n_timesteps:
                path = {
                    "observations": np.array(obervations),
                    "policy": np.array(action_probs),
                    "actions": np.array(actions),
                    "rewards": np.array(rewards),
                    "cumulative_returns": get_cumulative_returns(rewards),
                }
                paths.append(path)
                break
    return paths

# %%
from pprint import pprint

paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
pprint(paths[-1])

assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,) + observation_shape)
assert (paths[0]['actions'].shape == (5,))

print("It's ok")
# Out:
# {'actions': array([1, 0, 2, 0, 1]),
#  'cumulative_returns': array([-5., -4., -3., -2., -1.]),
#  'observations': array([[ 0.9963465 ,  0.08540337,  0.99996614,  0.00822863,  0.01366691,
#         -0.02968869],
#        [ 0.9969696 ,  0.07779254,  0.999954  ,  0.00959449, -0.08833051,
#          0.04176702],
#        [ 0.9978893 ,  0.06493787,  0.9999392 , -0.01102853, -0.03869639,
#         -0.2461655 ],
#        [ 0.9993558 ,  0.03588905,  0.9998489 , -0.01738247, -0.24617323,
#          0.17869745],
#        [ 0.9999969 , -0.00248648,  0.9999068 , -0.0136555 , -0.12995651,
#         -0.1476017 ]], dtype=float32),
#  'policy': array([[0.36998555, 0.33295286, 0.29706156],
#        [0.369649  , 0.33147177, 0.2988793 ],
#        [0.37701207, 0.32856923, 0.29441872],
#        [0.36745706, 0.33038265, 0.30216026],
#        [0.37449798, 0.3281263 , 0.2973757 ]], dtype=float32),
#  'rewards': array([-1., -1., -1., -1., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be:
# $$J_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, in this assignment we are going to use cumulative rewards instead of advantage:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Since we want to maximize the reward, we are going to minimize the corresponding surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps]
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    probs_all = agent.get_probs(observations)

    probs_for_actions = probs_all[torch.arange(batch_size), actions]
    old_probs_for_actions = old_probs[torch.arange(batch_size), actions]

    # Compute surrogate loss, aka importance-sampled policy gradient
    importance_sample_ratio = probs_for_actions / old_probs_for_actions
    loss = -(torch.mean(importance_sample_ratio * cumulative_returns))

    assert loss.ndim == 0
    return loss

# %% [markdown]
# We can ascend these gradients as long as our $\pi_\theta(a|s)$ satisfies the constraint
# $$\mathbb{E}_{s,\pi_{\theta_{t}}} \Big[ \operatorname{KL} \left( \pi_{\theta_{t}} (s) \:\|\: \pi_{\theta_{t+1}} (s) \right) \Big] < \alpha$$
#
#
# where
#
# $$\operatorname{KL} \left( p \| q \right) = \mathbb{E}_p \log \left( \frac p q \right)$$

# %%
def get_kl(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps] (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above).
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took.
    # You will also need to compute max KL over all timesteps.
    old_log_probs = torch.log(old_probs + 1e-10)

    # Using the quotient log rules here
    kl = torch.sum(old_probs * (old_log_probs - log_probs_all)) / batch_size

    assert kl.ndim == 0
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = torch.tensor(observations, dtype=torch.float32)

    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = (-probs_all * log_probs_all).sum(dim=1).mean(dim=0)

    assert entropy.ndim == 0
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x: torch.Tensor, fullstep: torch.Tensor, max_kl: float, max_backtracks: int = 10, backtrack_coef: float = 0.5):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    loss, _, = f(x)
    for stepfrac in backtrack_coef**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        if kl <= max_kl and new_loss < loss:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve $A x = b$ using conjugate gradients.
#
# In general, CG is an algorithm that solves $A x = b$ where $A$ is positive-defined. $A$ is the Hessian matrix so $A$ is positive-defined. You can find out more about CG [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method).

# %%
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using an iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros_like(b)
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = A.T @ A


def f_Ax(x):
    return torch.ravel(torch.tensor(A, dtype=torch.float32) @ x.reshape(-1, 1))


b = np.random.rand(8)
w = (np.linalg.inv(A.T @ A) @ A.T @ b.reshape(-1, 1)).reshape(-1)

print(w)
print(conjugate_gradient(f_Ax, torch.tensor(b, dtype=torch.float32)).numpy())
# Out:
# [  2255.62032912  -3260.46622911  -8755.30582754  -8359.86455456
#  -13972.21631188  11752.31828209   7209.9823672   16405.61345903]
# [  2247.0225  -3247.5413  -8719.549   -8326.301  -13915.097   11704.683
#    7180.6343  16338.536 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cumulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cumulative_returns - batch of cumulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = torch.tensor(observations, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int64)
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)
    old_probs = torch.tensor(old_probs, dtype=torch.float32)

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cumulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([torch.ravel(grad.detach()) for grad in grads])

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions, cumulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.reshape(-1) for grad in grads])

        kl_v = (flat_grad_kl * v).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([torch.ravel(grad) for grad in grads]).detach()

        return flat_grad_grad_kl + v * 0.1

    # Here we solve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [
            get_loss(agent, observations, actions, cumulative_returns, old_probs),
            get_kl(agent, observations, actions, cumulative_returns, old_probs),
        ]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count

# TRPO hyperparameter; controls how big KL divergence may be between the old and the new policy at every step.
max_kl = 0.01
numeptotal = 0  # Number of episodes we have completed so far.

start_time = time.time()

for i in count(1):
    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = {}
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 663
# Average sum of rewards per episode:       -74.41628959276018
# Std of rewards per episode:               17.292231582728302
# Time elapsed:                             0.38 mins
# KL between old and new distribution:      0.009992737
# Entropy:                                  0.024378939
# Surrogate loss:                           39.07827
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 1342
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               11.04580088269403
# Time elapsed:                             0.72 mins
# KL between old and new distribution:      0.009981365
# Entropy:                                  0.027973672
# Surrogate loss:                           37.045624
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 2015
# Average sum of rewards per episode:       -73.29569093610698
# Std of rewards per episode:               13.518033605017465
# Time elapsed:                             1.04 mins
# KL between old and new distribution:      0.00997765
# Entropy:                                  0.026865512
# Surrogate loss:                           37.81608
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 2695
# Average sum of rewards per episode:       -72.53235294117647
# Std of rewards per episode:               20.14795596972024
# Time elapsed:                             1.36 mins
# KL between old and new distribution:      0.009984814
# Entropy:                                  0.026931638
# Surrogate loss:                           38.945526
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 3369
# Average sum of rewards per episode:       -73.18694362017804
# Std of rewards per episode:               21.562635458787778
# Time elapsed:                             1.68 mins
# KL between old and new distribution:      0.009986134
# Entropy:                                  0.024369624
# Surrogate loss:                           39.641285
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 4048
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               13.069464233217989
# Time elapsed:                             1.99 mins
# KL between old and new distribution:      0.009968463
# Entropy:                                  0.029791558
# Surrogate loss:                           37.439823
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 4736
# Average sum of rewards per episode:       -71.67587209302326
# Std of rewards per episode:               11.855520711148753
# Time elapsed:                             2.31 mins
# KL between old and new distribution:      0.009998246
# Entropy:                                  0.023032278
# Surrogate loss:                           36.736168
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 5420
# Average sum of rewards per episode:       -72.10087719298245
# Std of rewards per episode:               13.824719336305112
# Time elapsed:                             2.63 mins
# KL between old and new distribution:      0.005958309
# Entropy:                                  0.025202224
# Surrogate loss:                           37.32022
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 6102
# Average sum of rewards per episode:       -72.31524926686217
# Std of rewards per episode:               12.341738389011198
# Time elapsed:                             2.96 mins
# KL between old and new distribution:      0.005392301
# Entropy:                                  0.023483489
# Surrogate loss:                           37.15851
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 6793
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               10.495486833566998
# Time elapsed:                             3.28 mins
# KL between old and new distribution:      0.009995038
# Entropy:                                  0.020009473
# Surrogate loss:                           36.349426
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 7481
# Average sum of rewards per episode:       -71.67587209302326
# Std of rewards per episode:               13.40886115145461
# Time elapsed:                             3.62 mins
# KL between old and new distribution:      0.00998799
# Entropy:                                  0.01923244
# Surrogate loss:                           37.005997
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 8172
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               10.153045461901389
# Time elapsed:                             3.94 mins
# KL between old and new distribution:      0.009973295
# Entropy:                                  0.022425244
# Surrogate loss:                           36.293217
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 8847
# Average sum of rewards per episode:       -73.07555555555555
# Std of rewards per episode:               12.508553912729253
# Time elapsed:                             4.26 mins
# KL between old and new distribution:      0.009994759
# Entropy:                                  0.023904711
# Surrogate loss:                           37.5087
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 9520
# Average sum of rewards per episode:       -73.29569093610698
# Std of rewards per episode:               15.975192390776085
# Time elapsed:                             4.57 mins
# KL between old and new distribution:      0.0064889165
# Entropy:                                  0.02385974
# Surrogate loss:                           38.32173
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 10187
# Average sum of rewards per episode:       -73.9640179910045
# Std of rewards per episode:               13.685322817433555
# Time elapsed:                             4.89 mins
# KL between old and new distribution:      0.009971504
# Entropy:                                  0.024841435
# Surrogate loss:                           38.144234
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 10851
# Average sum of rewards per episode:       -74.30271084337349
# Std of rewards per episode:               13.803818831688396
# Time elapsed:                             5.21 mins
# KL between old and new distribution:      0.009973012
# Entropy:                                  0.0258122
# Surrogate loss:                           38.30264
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 11523
# Average sum of rewards per episode:       -73.4077380952381
# Std of rewards per episode:               21.12189254976426
# Time elapsed:                             5.53 mins
# KL between old and new distribution:      0.009997632
# Entropy:                                  0.021174071
# Surrogate loss:                           39.63104
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 12218
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               10.900518865004479
# Time elapsed:                             5.85 mins
# KL between old and new distribution:      0.009969182
# Entropy:                                  0.027159821
# Surrogate loss:                           36.15522
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 12895
# Average sum of rewards per episode:       -72.85672082717873
# Std of rewards per episode:               14.91141255556031
# Time elapsed:                             6.20 mins
# KL between old and new distribution:      0.009978047
# Entropy:                                  0.02185794
# Surrogate loss:                           37.83006
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 13578
# Average sum of rewards per episode:       -72.20790629575403
# Std of rewards per episode:               14.94090248498698
# Time elapsed:                             6.52 mins
# KL between old and new distribution:      0.009987674
# Entropy:                                  0.020892771
# Surrogate loss:                           37.440624
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 14269
# Average sum of rewards per episode:       -71.36179450072359
# Std of rewards per episode:               20.33836605243416
# Time elapsed:                             6.83 mins
# KL between old and new distribution:      0.009982568
# Entropy:                                  0.024197169
# Surrogate loss:                           38.481846
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 14937
# Average sum of rewards per episode:       -73.85179640718563
# Std of rewards per episode:               15.10444316615967
# Time elapsed:                             7.15 mins
# KL between old and new distribution:      0.009995587
# Entropy:                                  0.024428112
# Surrogate loss:                           38.31243
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 15605
# Average sum of rewards per episode:       -73.85329341317366
# Std of rewards per episode:               22.914434131102592
# Time elapsed:                             7.46 mins
# KL between old and new distribution:      0.009983964
# Entropy:                                  0.020739984
# Surrogate loss:                           40.338116
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 16288
# Average sum of rewards per episode:       -72.20790629575403
# Std of rewards per episode:               15.329016175372635
# Time elapsed:                             7.78 mins
# KL between old and new distribution:      0.009972567
# Entropy:                                  0.023727635
# Surrogate loss:                           37.570133
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 16978
# Average sum of rewards per episode:       -71.46521739130435
# Std of rewards per episode:               14.03410262706326
# Time elapsed:                             8.10 mins
# KL between old and new distribution:      0.0099833235
# Entropy:                                  0.020647043
# Surrogate loss:                           37.013447
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 17673
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               11.029901250612399
# Time elapsed:                             8.43 mins
# KL between old and new distribution:      0.009984783
# Entropy:                                  0.020239653
# Surrogate loss:                           36.243065
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 18376
# Average sum of rewards per episode:       -70.12517780938833
# Std of rewards per episode:               10.05171438586394
# Time elapsed:                             8.75 mins
# KL between old and new distribution:      0.009986107
# Entropy:                                  0.0213193
# Surrogate loss:                           35.72132
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 19054
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               15.33989879710206
# Time elapsed:                             9.10 mins
# KL between old and new distribution:      0.009997802
# Entropy:                                  0.023646519
# Surrogate loss:                           37.91969
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 19727
# Average sum of rewards per episode:       -73.29717682020802
# Std of rewards per episode:               20.72592552958462
# Time elapsed:                             9.42 mins
# KL between old and new distribution:      0.009981324
# Entropy:                                  0.021607736
# Surrogate loss:                           39.454643
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 20406
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               14.564598774567397
# Time elapsed:                             9.74 mins
# KL between old and new distribution:      0.0099669015
# Entropy:                                  0.02132613
# Surrogate loss:                           37.621098
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 21091
# Average sum of rewards per episode:       -71.9941605839416
# Std of rewards per episode:               12.741333201067938
# Time elapsed:                             10.06 mins
# KL between old and new distribution:      0.009982027
# Entropy:                                  0.020475391
# Surrogate loss:                           37.0358
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 21779
# Average sum of rewards per episode:       -71.67587209302326
# Std of rewards per episode:               13.271905952482738
# Time elapsed:                             10.39 mins
# KL between old and new distribution:      0.009975837
# Entropy:                                  0.022569824
# Surrogate loss:                           36.96591
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 22445
# Average sum of rewards per episode:       -74.07657657657657
# Std of rewards per episode:               15.215227406678116
# Time elapsed:                             10.71 mins
# KL between old and new distribution:      0.009983237
# Entropy:                                  0.02234241
# Surrogate loss:                           38.48506
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 23116
# Average sum of rewards per episode:       -73.5171385991058
# Std of rewards per episode:               13.518191800204242
# Time elapsed:                             11.04 mins
# KL between old and new distribution:      0.009998498
# Entropy:                                  0.023421312
# Surrogate loss:                           37.88896
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 23793
# Average sum of rewards per episode:       -72.85672082717873
# Std of rewards per episode:               12.900889204821913
# Time elapsed:                             11.36 mins
# KL between old and new distribution:      0.009981624
# Entropy:                                  0.0189642
# Surrogate loss:                           37.524845
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 24484
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               13.370338551839279
# Time elapsed:                             11.71 mins
# KL between old and new distribution:      0.0099800965
# Entropy:                                  0.019026918
# Surrogate loss:                           36.854984
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 25170
# Average sum of rewards per episode:       -71.88775510204081
# Std of rewards per episode:               16.568893065302003
# Time elapsed:                             12.03 mins
# KL between old and new distribution:      0.005867885
# Entropy:                                  0.017272746
# Surrogate loss:                           37.78487
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 25867
# Average sum of rewards per episode:       -70.73744619799139
# Std of rewards per episode:               12.303255255878208
# Time elapsed:                             12.36 mins
# KL between old and new distribution:      0.009981976
# Entropy:                                  0.020111429
# Surrogate loss:                           36.325745
#
# ********** Iteration 39 ************
# Rollout
# Made rollout
# Total number of episodes:                 26556
# Average sum of rewards per episode:       -71.57039187227866
# Std of rewards per episode:               13.254724271795595
# Time elapsed:                             12.67 mins
# KL between old and new distribution:      0.009990473
# Entropy:                                  0.018602857
# Surrogate loss:                           36.89441
#
# ********** Iteration 40 ************
# Rollout
# Made rollout
# Total number of episodes:                 27251
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               12.752701026400821
# Time elapsed:                             13.00 mins
# KL between old and new distribution:      0.009992777
# Entropy:                                  0.016889066
# Surrogate loss:                           36.554375
#
# ********** Iteration 41 ************
# Rollout
# Made rollout
# Total number of episodes:                 27954
# Average sum of rewards per episode:       -70.12517780938833
# Std of rewards per episode:               9.403623915774315
# Time elapsed:                             13.32 mins
# KL between old and new distribution:      0.004587563
# Entropy:                                  0.016241435
# Surrogate loss:                           35.67676
#
# ********** Iteration 42 ************
# Rollout
# Made rollout
# Total number of episodes:                 28656
# Average sum of rewards per episode:       -70.22649572649573
# Std of rewards per episode:               11.977126061319058
# Time elapsed:                             13.64 mins
# KL between old and new distribution:      0.0099809775
# Entropy:                                  0.016487222
# Surrogate loss:                           36.07533
#
# ********** Iteration 43 ************
# Rollout
# Made rollout
# Total number of episodes:                 29357
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               12.658836001989146
# Time elapsed:                             13.95 mins
# KL between old and new distribution:      0.009989397
# Entropy:                                  0.016446164
# Surrogate loss:                           36.2022
#
# ********** Iteration 44 ************
# Rollout
# Made rollout
# Total number of episodes:                 30052
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               14.778109978880968
# Time elapsed:                             14.29 mins
# KL between old and new distribution:      0.00997976
# Entropy:                                  0.017371694
# Surrogate loss:                           36.87602
#
# ********** Iteration 45 ************
# Rollout
# Made rollout
# Total number of episodes:                 30743
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               12.587825965677094
# Time elapsed:                             14.61 mins
# KL between old and new distribution:      0.008470731
# Entropy:                                  0.01957501
# Surrogate loss:                           36.673977
#
# ********** Iteration 46 ************
# Rollout
# Made rollout
# Total number of episodes:                 31432
# Average sum of rewards per episode:       -71.5732946298984
# Std of rewards per episode:               26.215766221481605
# Time elapsed:                             14.93 mins
# KL between old and new distribution:      0.009987877
# Entropy:                                  0.016946286
# Surrogate loss:                           40.452248
#
# ********** Iteration 47 ************
# Rollout
# Made rollout
# Total number of episodes:                 32123
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               14.788390326423654
# Time elapsed:                             15.24 mins
# KL between old and new distribution:      0.009999093
# Entropy:                                  0.02062083
# Surrogate loss:                           37.09693
#
# ********** Iteration 48 ************
# Rollout
# Made rollout
# Total number of episodes:                 32797
# Average sum of rewards per episode:       -73.18545994065282
# Std of rewards per episode:               16.226138267233715
# Time elapsed:                             15.56 mins
# KL between old and new distribution:      0.0056851986
# Entropy:                                  0.018491054
# Surrogate loss:                           38.320374
#
# ********** Iteration 49 ************
# Rollout
# Made rollout
# Total number of episodes:                 33483
# Average sum of rewards per episode:       -71.88775510204081
# Std of rewards per episode:               15.30460196529522
# Time elapsed:                             15.89 mins
# KL between old and new distribution:      0.009988293
# Entropy:                                  0.020029426
# Surrogate loss:                           37.491894
#
# ********** Iteration 50 ************
# Rollout
# Made rollout
# Total number of episodes:                 34162
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               14.614667614482483
# Time elapsed:                             16.20 mins
# KL between old and new distribution:      0.009999826
# Entropy:                                  0.021292424
# Surrogate loss:                           37.659676
#
# ********** Iteration 51 ************
# Rollout
# Made rollout
# Total number of episodes:                 34847
# Average sum of rewards per episode:       -71.9941605839416
# Std of rewards per episode:               14.161012409801891
# Time elapsed:                             16.52 mins
# KL between old and new distribution:      0.009967929
# Entropy:                                  0.022613974
# Surrogate loss:                           37.268726
#
# ********** Iteration 52 ************
# Rollout
# Made rollout
# Total number of episodes:                 35526
# Average sum of rewards per episode:       -72.63917525773196
# Std of rewards per episode:               13.70177836614323
# Time elapsed:                             16.83 mins
# KL between old and new distribution:      0.0099792015
# Entropy:                                  0.021488547
# Surrogate loss:                           37.531036
#
# ********** Iteration 53 ************
# Rollout
# Made rollout
# Total number of episodes:                 36181
# Average sum of rewards per episode:       -75.33740458015266
# Std of rewards per episode:               16.56642579112355
# Time elapsed:                             17.18 mins
# KL between old and new distribution:      0.009984686
# Entropy:                                  0.023830982
# Surrogate loss:                           39.376984
#
# ********** Iteration 54 ************
# Rollout
# Made rollout
# Total number of episodes:                 36842
# Average sum of rewards per episode:       -74.64447806354009
# Std of rewards per episode:               15.00103134855469
# Time elapsed:                             17.50 mins
# KL between old and new distribution:      0.009998423
# Entropy:                                  0.02617095
# Surrogate loss:                           38.73667
#
# ********** Iteration 55 ************
# Rollout
# Made rollout
# Total number of episodes:                 37491
# Average sum of rewards per episode:       -76.04314329738058
# Std of rewards per episode:               14.985601306391898
# Time elapsed:                             17.81 mins
# KL between old and new distribution:      0.009982439
# Entropy:                                  0.029323349
# Surrogate loss:                           39.281723
#
# ********** Iteration 56 ************
# Rollout
# Made rollout
# Total number of episodes:                 38149
# Average sum of rewards per episode:       -74.98936170212765
# Std of rewards per episode:               19.099599986737054
# Time elapsed:                             18.12 mins
# KL between old and new distribution:      0.009992696
# Entropy:                                  0.026809333
# Surrogate loss:                           39.759758
#
# ********** Iteration 57 ************
# Rollout
# Made rollout
# Total number of episodes:                 38827
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               16.155305971554263
# Time elapsed:                             18.44 mins
# KL between old and new distribution:      0.009986299
# Entropy:                                  0.023865959
# Surrogate loss:                           38.092224
#
# ********** Iteration 58 ************
# Rollout
# Made rollout
# Total number of episodes:                 39514
# Average sum of rewards per episode:       -71.78165938864629
# Std of rewards per episode:               15.182502038015597
# Time elapsed:                             18.76 mins
# KL between old and new distribution:      0.009978329
# Entropy:                                  0.020997636
# Surrogate loss:                           37.33811
#
# ********** Iteration 59 ************
# Rollout
# Made rollout
# Total number of episodes:                 40210
# Average sum of rewards per episode:       -70.84051724137932
# Std of rewards per episode:               11.935247796436672
# Time elapsed:                             19.07 mins
# KL between old and new distribution:      0.009984325
# Entropy:                                  0.01898078
# Surrogate loss:                           36.277744
#
# ********** Iteration 60 ************
# Rollout
# Made rollout
# Total number of episodes:                 40905
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               11.721640290277799
# Time elapsed:                             19.40 mins
# KL between old and new distribution:      0.009982233
# Entropy:                                  0.02057075
# Surrogate loss:                           36.337284
#
# ********** Iteration 61 ************
# Rollout
# Made rollout
# Total number of episodes:                 41594
# Average sum of rewards per episode:       -71.57039187227866
# Std of rewards per episode:               13.475820198975473
# Time elapsed:                             19.75 mins
# KL between old and new distribution:      0.009992632
# Entropy:                                  0.01992299
# Surrogate loss:                           36.96522
#
# ********** Iteration 62 ************
# Rollout
# Made rollout
# Total number of episodes:                 42272
# Average sum of rewards per episode:       -72.74778761061947
# Std of rewards per episode:               15.266650163009846
# Time elapsed:                             20.07 mins
# KL between old and new distribution:      0.009974188
# Entropy:                                  0.017513406
# Surrogate loss:                           37.845886
#
# ********** Iteration 63 ************
# Rollout
# Made rollout
# Total number of episodes:                 42968
# Average sum of rewards per episode:       -70.84051724137932
# Std of rewards per episode:               13.68347529994429
# Time elapsed:                             20.39 mins
# KL between old and new distribution:      0.009983353
# Entropy:                                  0.016678717
# Surrogate loss:                           36.62406
#
# ********** Iteration 64 ************
# Rollout
# Made rollout
# Total number of episodes:                 43659
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               12.05338304028524
# Time elapsed:                             20.71 mins
# KL between old and new distribution:      0.009999913
# Entropy:                                  0.015071943
# Surrogate loss:                           36.58764
#
# ********** Iteration 65 ************
# Rollout
# Made rollout
# Total number of episodes:                 44361
# Average sum of rewards per episode:       -70.22649572649573
# Std of rewards per episode:               11.821017256295182
# Time elapsed:                             21.03 mins
# KL between old and new distribution:      0.009992763
# Entropy:                                  0.01910039
# Surrogate loss:                           36.02582
#
# ********** Iteration 66 ************
# Rollout
# Made rollout
# Total number of episodes:                 45042
# Average sum of rewards per episode:       -72.42290748898678
# Std of rewards per episode:               15.841737593773397
# Time elapsed:                             21.35 mins
# KL between old and new distribution:      0.009980744
# Entropy:                                  0.022226768
# Surrogate loss:                           37.847694
#
# ********** Iteration 67 ************
# Rollout
# Made rollout
# Total number of episodes:                 45711
# Average sum of rewards per episode:       -73.73991031390135
# Std of rewards per episode:               20.717068502715737
# Time elapsed:                             21.67 mins
# KL between old and new distribution:      0.009969894
# Entropy:                                  0.022877099
# Surrogate loss:                           39.658443
#
# ********** Iteration 68 ************
# Rollout
# Made rollout
# Total number of episodes:                 46399
# Average sum of rewards per episode:       -71.67587209302326
# Std of rewards per episode:               11.729306336967694
# Time elapsed:                             21.99 mins
# KL between old and new distribution:      0.009999545
# Entropy:                                  0.018292243
# Surrogate loss:                           36.671337
#
# ********** Iteration 69 ************
# Rollout
# Made rollout
# Total number of episodes:                 47074
# Average sum of rewards per episode:       -73.07555555555555
# Std of rewards per episode:               17.536296609188387
# Time elapsed:                             22.33 mins
# KL between old and new distribution:      0.009996562
# Entropy:                                  0.019703418
# Surrogate loss:                           38.48499
#
# ********** Iteration 70 ************
# Rollout
# Made rollout
# Total number of episodes:                 47775
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               10.438771713576587
# Time elapsed:                             22.65 mins
# KL between old and new distribution:      0.009975621
# Entropy:                                  0.019065749
# Surrogate loss:                           35.792564
#
# ********** Iteration 71 ************
# Rollout
# Made rollout
# Total number of episodes:                 48468
# Average sum of rewards per episode:       -71.15151515151516
# Std of rewards per episode:               12.89770446756316
# Time elapsed:                             22.97 mins
# KL between old and new distribution:      0.009998592
# Entropy:                                  0.017830336
# Surrogate loss:                           36.629505
#
# ********** Iteration 72 ************
# Rollout
# Made rollout
# Total number of episodes:                 49167
# Average sum of rewards per episode:       -70.53218884120172
# Std of rewards per episode:               14.649262616561089
# Time elapsed:                             23.28 mins
# KL between old and new distribution:      0.009988405
# Entropy:                                  0.017509203
# Surrogate loss:                           36.703323
#
# ********** Iteration 73 ************
# Rollout
# Made rollout
# Total number of episodes:                 49867
# Average sum of rewards per episode:       -70.43
# Std of rewards per episode:               10.291714420556263
# Time elapsed:                             23.60 mins
# KL between old and new distribution:      0.009975728
# Entropy:                                  0.019946646
# Surrogate loss:                           35.912914
#
# ********** Iteration 74 ************
# Rollout
# Made rollout
# Total number of episodes:                 50566
# Average sum of rewards per episode:       -70.53218884120172
# Std of rewards per episode:               12.247567026565093
# Time elapsed:                             23.92 mins
# KL between old and new distribution:      0.0099803945
# Entropy:                                  0.020540183
# Surrogate loss:                           36.231426
#
# ********** Iteration 75 ************
# Rollout
# Made rollout
# Total number of episodes:                 51256
# Average sum of rewards per episode:       -71.46521739130435
# Std of rewards per episode:               13.9799890743147
# Time elapsed:                             24.24 mins
# KL between old and new distribution:      0.009985572
# Entropy:                                  0.02298144
# Surrogate loss:                           36.992424
#
# ********** Iteration 76 ************
# Rollout
# Made rollout
# Total number of episodes:                 51951
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               10.351436942672116
# Time elapsed:                             24.56 mins
# KL between old and new distribution:      0.009957542
# Entropy:                                  0.023125745
# Surrogate loss:                           36.15687
#
# ********** Iteration 77 ************
# Rollout
# Made rollout
# Total number of episodes:                 52628
# Average sum of rewards per episode:       -72.85672082717873
# Std of rewards per episode:               11.875219156509077
# Time elapsed:                             24.88 mins
# KL between old and new distribution:      0.009995168
# Entropy:                                  0.025078308
# Surrogate loss:                           37.307602
#
# ********** Iteration 78 ************
# Rollout
# Made rollout
# Total number of episodes:                 53308
# Average sum of rewards per episode:       -72.53088235294118
# Std of rewards per episode:               13.76469009237405
# Time elapsed:                             25.23 mins
# KL between old and new distribution:      0.009989384
# Entropy:                                  0.024566593
# Surrogate loss:                           37.46187
#
# ********** Iteration 79 ************
# Rollout
# Made rollout
# Total number of episodes:                 53998
# Average sum of rewards per episode:       -71.46521739130435
# Std of rewards per episode:               12.55340275004809
# Time elapsed:                             25.55 mins
# KL between old and new distribution:      0.009994407
# Entropy:                                  0.024966327
# Surrogate loss:                           36.69547
#
# ********** Iteration 80 ************
# Rollout
# Made rollout
# Total number of episodes:                 54684
# Average sum of rewards per episode:       -71.88775510204081
# Std of rewards per episode:               12.980157380825052
# Time elapsed:                             25.87 mins
# KL between old and new distribution:      0.009993213
# Entropy:                                  0.02621398
# Surrogate loss:                           36.997078
#
# ********** Iteration 81 ************
# Rollout
# Made rollout
# Total number of episodes:                 55374
# Average sum of rewards per episode:       -71.46521739130435
# Std of rewards per episode:               13.363787605152949
# Time elapsed:                             26.19 mins
# KL between old and new distribution:      0.0099956
# Entropy:                                  0.022899654
# Surrogate loss:                           36.863064
#
# ********** Iteration 82 ************
# Rollout
# Made rollout
# Total number of episodes:                 56069
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               13.195857836620709
# Time elapsed:                             26.52 mins
# KL between old and new distribution:      0.009531815
# Entropy:                                  0.019331763
# Surrogate loss:                           36.632465
#
# ********** Iteration 83 ************
# Rollout
# Made rollout
# Total number of episodes:                 56754
# Average sum of rewards per episode:       -71.9941605839416
# Std of rewards per episode:               14.766996968844492
# Time elapsed:                             26.83 mins
# KL between old and new distribution:      0.00999468
# Entropy:                                  0.016635843
# Surrogate loss:                           37.41651
#
# ********** Iteration 84 ************
# Rollout
# Made rollout
# Total number of episodes:                 57457
# Average sum of rewards per episode:       -70.12517780938833
# Std of rewards per episode:               11.350674675104036
# Time elapsed:                             27.15 mins
# KL between old and new distribution:      0.009986297
# Entropy:                                  0.015206632
# Surrogate loss:                           35.904
#
# ********** Iteration 85 ************
# Rollout
# Made rollout
# Total number of episodes:                 58153
# Average sum of rewards per episode:       -70.84051724137932
# Std of rewards per episode:               13.149739815058158
# Time elapsed:                             27.47 mins
# KL between old and new distribution:      0.008392767
# Entropy:                                  0.014289545
# Surrogate loss:                           36.551037
#
# ********** Iteration 86 ************
# Rollout
# Made rollout
# Total number of episodes:                 58861
# Average sum of rewards per episode:       -69.62288135593221
# Std of rewards per episode:               10.226965941849718
# Time elapsed:                             27.81 mins
# KL between old and new distribution:      0.009993328
# Entropy:                                  0.015166858
# Surrogate loss:                           35.482117
#
# ********** Iteration 87 ************
# Rollout
# Made rollout
# Total number of episodes:                 59561
# Average sum of rewards per episode:       -70.43
# Std of rewards per episode:               11.461212227085133
# Time elapsed:                             28.13 mins
# KL between old and new distribution:      0.009977262
# Entropy:                                  0.014459671
# Surrogate loss:                           36.075226
#
# ********** Iteration 88 ************
# Rollout
# Made rollout
# Total number of episodes:                 60260
# Average sum of rewards per episode:       -70.53218884120172
# Std of rewards per episode:               10.545495533104692
# Time elapsed:                             28.45 mins
# KL between old and new distribution:      0.0012111937
# Entropy:                                  0.0145924
# Surrogate loss:                           36.03666
#
# ********** Iteration 89 ************
# Rollout
# Made rollout
# Total number of episodes:                 60958
# Average sum of rewards per episode:       -70.63610315186246
# Std of rewards per episode:               19.964422876785427
# Time elapsed:                             28.77 mins
# KL between old and new distribution:      0.00999481
# Entropy:                                  0.014799702
# Surrogate loss:                           38.04939
#
# ********** Iteration 90 ************
# Rollout
# Made rollout
# Total number of episodes:                 61662
# Average sum of rewards per episode:       -70.02414772727273
# Std of rewards per episode:               12.71053325095494
# Time elapsed:                             29.09 mins
# KL between old and new distribution:      0.009992835
# Entropy:                                  0.0160039
# Surrogate loss:                           36.06689
#
# ********** Iteration 91 ************
# Rollout
# Made rollout
# Total number of episodes:                 62367
# Average sum of rewards per episode:       -69.92340425531916
# Std of rewards per episode:               11.508730194098273
# Time elapsed:                             29.41 mins
# KL between old and new distribution:      0.009999678
# Entropy:                                  0.016235538
# Surrogate loss:                           35.768436
#
# ********** Iteration 92 ************
# Rollout
# Made rollout
# Total number of episodes:                 63047
# Average sum of rewards per episode:       -72.53088235294118
# Std of rewards per episode:               15.444461765353083
# Time elapsed:                             29.73 mins
# KL between old and new distribution:      0.009975626
# Entropy:                                  0.017346809
# Surrogate loss:                           37.732216
#
# ********** Iteration 93 ************
# Rollout

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.cc/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the MCTS seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about TRPO in the [original paper](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cumulative rewards similar to `get_cumulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gym.openai.com/envs#mujoco)
# * [Box2d robot](https://gym.openai.com/envs/BipedalWalker-v2)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use a fully factorized gaussian (basically a vector of gaussians).
#
# __Bonus task__: compare the performance of the continuous action space method to action space discretization.
